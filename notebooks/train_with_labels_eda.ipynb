# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = catalog.load("light_train")
train.set_index('index', inplace=True)
display(train.head())
# Out:
# [04/04/23 18:49:12] INFO     Loading data from 'light_train' (PickleDataSet)...                 ]8;id=90292;file:///Users/iferreiro/miniconda3/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=188834;file:///Users/iferreiro/miniconda3/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#               session_id  elapsed_time      event_name   name  level  page  \
# index
# 0      20090312431273200             0  cutscene_click  basic      0   NaN
# 1      20090312431273200          1323    person_click  basic      0   NaN
# 2      20090312431273200           831    person_click  basic      0   NaN
# 3      20090312431273200          1147    person_click  basic      0   NaN
# 4      20090312431273200          1863    person_click  basic      0   NaN
#
#        room_coor_x  room_coor_y  screen_coor_x  screen_coor_y  hover_duration  \
# index
# 0           -414.0     -159.375          380.0          494.0             NaN
# 1           -414.0     -159.375          380.0          494.0             NaN
# 2           -414.0     -159.375          380.0          494.0             NaN
# 3           -414.0     -159.375          380.0          494.0             NaN
# 4           -413.0     -159.375          381.0          494.0             NaN
#
#                                 text    fqid                       room_fqid  \
# index
# 0                          undefined   intro  tunic.historicalsociety.closet
# 1      Whatcha doing over there, Jo?  gramps  tunic.historicalsociety.closet
# 2             Just talking to Teddy.  gramps  tunic.historicalsociety.closet
# 3         I gotta run to my meeting!  gramps  tunic.historicalsociety.closet
# 4                Can I come, Gramps?  gramps  tunic.historicalsociety.closet
#
#                                                text_fqid level_group
# index
# 0                   tunic.historicalsociety.closet.intro         0-4
# 1      tunic.historicalsociety.closet.gramps.intro_0_...         0-4
# 2      tunic.historicalsociety.closet.gramps.intro_0_...         0-4
# 3      tunic.historicalsociety.closet.gramps.intro_0_...         0-4
# 4      tunic.historicalsociety.closet.gramps.intro_0_...         0-4

# %%
train_labels = catalog.load("train_labels")
display(train_labels.head())
# Out:
# [04/04/23 18:49:09] INFO     Loading data from 'train_labels' (CSVDataSet)...                   ]8;id=803066;file:///Users/iferreiro/miniconda3/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=274727;file:///Users/iferreiro/miniconda3/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#              session_id  correct
# 0  20090312431273200_q1        1
# 1  20090312433251036_q1        0
# 2  20090314121766812_q1        1
# 3  20090314363702160_q1        1
# 4  20090314441803444_q1        1

# %%
train_labels = catalog.load("light_test")
display(train_labels.head())
